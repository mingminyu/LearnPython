# %% [markdown]
# # 除以 2 并且向下取整

# %%
print(16 // 2)
print(17 // 2)
# Out:
# 8
# 8

# %%
# 使用位运算符
print(16 >> 1)
print(17 >> 1)
# Out:
# 8
# 8

# %% [markdown]
# # 判断奇偶数

# %%
print(16 % 2 == 0)
print(17 % 2 == 0)
# Out:
# True
# False

# %%
print(16 & 1 == 0)
print(17 & 1 == 0)
# Out:
# True
# False
