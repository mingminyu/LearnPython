# %%
import random
from tenacity import retry


@retry
def do_something_unreliable():
    num = random.randint(0, 10)

    if num >= 5:
        print(num)
        raise IOError(f"Retry {num}: something is wrong!")
    else:
        return "Awesome sauce!"


do_something_unreliable()
# Out:
# 7
# 10
# 7
# 5
# 'Awesome sauce!'

# %% [markdown]
# # Basic Retry

# %%
@retry
def never_gonna_give_you_up():
    print("Retry forever ignoring Exceptions, don't wait between retries")
    raise Exception


never_gonna_give_you_up()

# %%
from tenacity import stop_after_attempt


@retry(stop=stop_after_attempt(7))
def stop_after_7_attempts():
    print("Stopping after 7 attempts")
    raise Exception


stop_after_7_attempts()
# Out:
# Stopping after 7 attempts
# Stopping after 7 attempts
# Stopping after 7 attempts
# Stopping after 7 attempts
# Stopping after 7 attempts
# Stopping after 7 attempts
# Stopping after 7 attempts
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     432                 try:
# --> 433                     result = fn(*args, **kwargs)
#     434                 except BaseException:  # noqa: B902
#
# <ipython-input-15-f3a72721f6e7> in stop_after_7_attempts()
#       6     print("Stopping after 7 attempts")
# ----> 7     raise Exception
#       8
#
# Exception:
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-15-f3a72721f6e7> in <module>
#       8
#       9
# ---> 10 stop_after_7_attempts()
#      11
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     337         @_utils.wraps(f)
#     338         def wrapped_f(*args, **kw):
# --> 339             return self(f, *args, **kw)
#     340
#     341         def retry_with(*args, **kwargs):
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     428         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     429         while True:
# --> 430             do = self.iter(retry_state=retry_state)
#     431             if isinstance(do, DoAttempt):
#     432                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     377             if self.reraise:
#     378                 raise retry_exc.reraise()
# --> 379             six.raise_from(retry_exc, fut.exception())
#     380
#     381         if self.wait:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\six.py in raise_from(value, from_value)
#
# RetryError: RetryError[<Future at 0x1ee58908d30 state=finished raised Exception>]

# %%
import time
from tenacity import stop_after_delay

# `stop_after_delay` 用于表示超时时间，即运行超过设置 timeout 值后，不再 retry

@retry(stop=stop_after_delay(1))
def stop_after_10s():
    print("Stopping after 10 seconds")
    time.sleep(0.1)
    raise Exception


stop_after_10s()
# Out:
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# Stopping after 10 seconds
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     432                 try:
# --> 433                     result = fn(*args, **kwargs)
#     434                 except BaseException:  # noqa: B902
#
# <ipython-input-21-d748c9a7d1ab> in stop_after_10s()
#       9     time.sleep(0.1)
# ---> 10     raise Exception
#      11
#
# Exception:
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-21-d748c9a7d1ab> in <module>
#      11
#      12
# ---> 13 stop_after_10s()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     337         @_utils.wraps(f)
#     338         def wrapped_f(*args, **kw):
# --> 339             return self(f, *args, **kw)
#     340
#     341         def retry_with(*args, **kwargs):
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     428         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     429         while True:
# --> 430             do = self.iter(retry_state=retry_state)
#     431             if isinstance(do, DoAttempt):
#     432                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     377             if self.reraise:
#     378                 raise retry_exc.reraise()
# --> 379             six.raise_from(retry_exc, fut.exception())
#     380
#     381         if self.wait:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\six.py in raise_from(value, from_value)
#
# RetryError: RetryError[<Future at 0x1ee5998cb20 state=finished raised Exception>]

# %%
@retry(stop=(stop_after_delay(5) | stop_after_attempt(10)))
def stop_after_10s_or_5_retries():
    print("Stopping after 10 seconds or 5 retries")
    time.sleep(1)
    raise Exception


stop_after_10s_or_5_retries()
# Out:
# Stopping after 10 seconds or 5 retries
# Stopping after 10 seconds or 5 retries
# Stopping after 10 seconds or 5 retries
# Stopping after 10 seconds or 5 retries
# Stopping after 10 seconds or 5 retries
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     432                 try:
# --> 433                     result = fn(*args, **kwargs)
#     434                 except BaseException:  # noqa: B902
#
# <ipython-input-24-26bf21d8b7a3> in stop_after_10s_or_5_retries()
#       4     time.sleep(1)
# ----> 5     raise Exception
#       6
#
# Exception:
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-24-26bf21d8b7a3> in <module>
#       6
#       7
# ----> 8 stop_after_10s_or_5_retries()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     337         @_utils.wraps(f)
#     338         def wrapped_f(*args, **kw):
# --> 339             return self(f, *args, **kw)
#     340
#     341         def retry_with(*args, **kwargs):
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     428         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     429         while True:
# --> 430             do = self.iter(retry_state=retry_state)
#     431             if isinstance(do, DoAttempt):
#     432                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     377             if self.reraise:
#     378                 raise retry_exc.reraise()
# --> 379             six.raise_from(retry_exc, fut.exception())
#     380
#     381         if self.wait:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\six.py in raise_from(value, from_value)
#
# RetryError: RetryError[<Future at 0x1ee588a8a90 state=finished raised Exception>]

# %% [markdown]
# # Waiting before retrying

# %%
from tenacity import wait_fixed


# wait_fixed 用于设置等待时长

@retry(wait=wait_fixed(2))
def wait_2s():
    print("Wait 2 second between retries")
    raise Exception


wait_2s()
# Out:
# Wait 2 second between retries
# Wait 2 second between retries
# Wait 2 second between retries
# Wait 2 second between retries
# Wait 2 second between retries
# Wait 2 second between retries
# Wait 2 second between retries
# Wait 2 second between retries
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-01391d6f8398> in <module>
#       7
#       8
# ----> 9 wait_2s()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     337         @_utils.wraps(f)
#     338         def wrapped_f(*args, **kw):
# --> 339             return self(f, *args, **kw)
#     340
#     341         def retry_with(*args, **kwargs):
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     438             elif isinstance(do, DoSleep):
#     439                 retry_state.prepare_for_next_attempt()
# --> 440                 self.sleep(do)
#     441             else:
#     442                 return do
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\nap.py in sleep(seconds)
#      26     This is the default strategy, and may be mocked out for unit testing.
#      27     """
# ---> 28     time.sleep(seconds)
#      29
#      30
#
# KeyboardInterrupt:

# %%
from tenacity import retry
from tenacity import wait_random, wait_exponential

# wait_random 用于设置随机等待时长
# wait_exponential 用于设置指数等等待时长


@retry(wait=wait_random(min=1, max=10))
def wait_random_1_to_2s():
    print("Randomly wait 1 to 2 seconds between retries")
    raise Exception


wait_random_1_to_2s()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-920a303b821f> in <module>
#       2
#       3
# ----> 4 @retry(wait=wait_random(min=1, max=10))
#       5 def wait_random_1_to_2s():
#       6     print("Randomly wait 1 to 2 seconds between retries")
#
# NameError: name 'retry' is not defined

# %%
from tenacity import retry
from tenacity import wait_random, wait_exponential
from datetime import datetime


@retry(wait=wait_exponential(multiplier=1, min=4, max=10))
def wait_exponential_1():
    print(datetime.now())
    print("Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards")
    raise Exception


wait_exponential_1()
# Out:
# 2022-07-15 12:13:27.494023
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:13:31.495644
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:13:35.498500
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:13:39.502277
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:13:47.503681
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:13:57.506610
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:14:07.509433
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:14:17.513592
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:14:27.518095
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:14:37.519227
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# 2022-07-15 12:14:47.521595
# Wait 2^x * 1 second between each retry starting with 4 seconds, then up to 10 seconds, then 10 seconds afterwards
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1a85e0096e7b> in <module>
#      11
#      12
# ---> 13 wait_exponential_1()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     337         @_utils.wraps(f)
#     338         def wrapped_f(*args, **kw):
# --> 339             return self(f, *args, **kw)
#     340
#     341         def retry_with(*args, **kwargs):
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     438             elif isinstance(do, DoSleep):
#     439                 retry_state.prepare_for_next_attempt()
# --> 440                 self.sleep(do)
#     441             else:
#     442                 return do
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\nap.py in sleep(seconds)
#      26     This is the default strategy, and may be mocked out for unit testing.
#      27     """
# ---> 28     time.sleep(seconds)
#      29
#      30
#
# KeyboardInterrupt:

# %%
@retry(wait=wait_fixed(3) + wait_random(0, 2))
def wait_fixed_jitter():
    print("Wait at least 3 seconds, and add up to 2 seconds of random delay")
    raise Exception

# %%
from tenacity import wait_random_exponential

# wait_random_exponential 用于设置指数时间


@retry(wait=wait_random_exponential(multiplier=1, max=60))
def wait_exponential_jitter():
    print("Randomly wait up to 2^x * 1 seconds between each retry until the range reaches 60 seconds, then randomly up to 60 seconds afterwards")
    raise Exception

# %%
from tenacity import wait_chain, wait_fixed


@retry(wait=wait_chain(
    *[wait_fixed(3) for i in range(3)] +
     [wait_fixed(7) for i in range(2)] +
     [wait_fixed(9)]))
def wait_fixed_chained():
    print("Wait 3s for 3 attempts, 7s for the next 2 attempts and 9s for all attempts thereafter")
    raise Exception


wait_fixed_chained()
# Out:
# Wait 3s for 3 attempts, 7s for the next 2 attempts and 9s for all attempts thereafter
# Wait 3s for 3 attempts, 7s for the next 2 attempts and 9s for all attempts thereafter
# Wait 3s for 3 attempts, 7s for the next 2 attempts and 9s for all attempts thereafter
# Wait 3s for 3 attempts, 7s for the next 2 attempts and 9s for all attempts thereafter
# Wait 3s for 3 attempts, 7s for the next 2 attempts and 9s for all attempts thereafter
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4f5ab2371e06> in <module>
#      11
#      12
# ---> 13 wait_fixed_chained()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     337         @_utils.wraps(f)
#     338         def wrapped_f(*args, **kw):
# --> 339             return self(f, *args, **kw)
#     340
#     341         def retry_with(*args, **kwargs):
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     438             elif isinstance(do, DoSleep):
#     439                 retry_state.prepare_for_next_attempt()
# --> 440                 self.sleep(do)
#     441             else:
#     442                 return do
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\nap.py in sleep(seconds)
#      26     This is the default strategy, and may be mocked out for unit testing.
#      27     """
# ---> 28     time.sleep(seconds)
#      29
#      30
#
# KeyboardInterrupt:

# %% [markdown]
# # Whether to retry

# %%
import time
from tenacity import retry_if_exception_type
from tenacity.retry import retry_if_exception_type
from tenacity.retry import retry_if_not_exception_type
from tenacity import retry
from tenacity import wait_fixed
from tenacity import stop_after_attempt, stop_after_delay

# %%
class ClientError(Exception):
    """Some type of client error."""

@retry(
    retry=retry_if_exception_type(IOError),
    wait=wait_fixed(2),
    stop=(stop_after_delay(4) | stop_after_attempt(3))
)
def might_io_error():
    time.sleep(3)
    print("Retry forever with no wait if an IOError occurs, raise any other errors")
    raise IOError


might_io_error()
# Out:
# Retry forever with no wait if an IOError occurs, raise any other errors
# Retry forever with no wait if an IOError occurs, raise any other errors
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     406                 try:
# --> 407                     result = fn(*args, **kwargs)
#     408                 except BaseException:  # noqa: B902
#
# <ipython-input-5-ffae36fda906> in might_io_error()
#      11     print("Retry forever with no wait if an IOError occurs, raise any other errors")
# ---> 12     raise IOError
#      13
#
# OSError:
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-5-ffae36fda906> in <module>
#      13
#      14
# ---> 15 might_io_error()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     402         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     403         while True:
# --> 404             do = self.iter(retry_state=retry_state)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     359             if self.reraise:
#     360                 raise retry_exc.reraise()
# --> 361             raise retry_exc from fut.exception()
#     362
#     363         if self.wait:
#
# RetryError: RetryError[<Future at 0x17900995ca0 state=finished raised OSError>]

# %%
@retry(
    retry=retry_if_not_exception_type(ClientError),
    wait=wait_fixed(2),
    stop=stop_after_attempt(3)
)
def might_client_error():
    print("Retry forever with no wait if any error other than ClientError occurs. Immediately raise ClientError.")
    raise ClientError


might_client_error()
# Out:
# Retry forever with no wait if any error other than ClientError occurs. Immediately raise ClientError.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-7-4954071a4221> in <module>
#       9
#      10
# ---> 11 might_client_error()
#      12
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     402         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     403         while True:
# --> 404             do = self.iter(retry_state=retry_state)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     347         is_explicit_retry = retry_state.outcome.failed and isinstance(retry_state.outcome.exception(), TryAgain)
#     348         if not (is_explicit_retry or self.retry(retry_state=retry_state)):
# --> 349             return fut.result()
#     350
#     351         if self.after is not None:
#
# D:\bigdata\anaconda3\envs\py39\lib\concurrent\futures\_base.py in result(self, timeout)
#     431                 raise CancelledError()
#     432             elif self._state == FINISHED:
# --> 433                 return self.__get_result()
#     434
#     435             self._condition.wait(timeout)
#
# D:\bigdata\anaconda3\envs\py39\lib\concurrent\futures\_base.py in __get_result(self)
#     387     def __get_result(self):
#     388         if self._exception:
# --> 389             raise self._exception
#     390         else:
#     391             return self._result
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
# --> 407                     result = fn(*args, **kwargs)
#     408                 except BaseException:  # noqa: B902
#     409                     retry_state.set_exception(sys.exc_info())
#
# <ipython-input-7-4954071a4221> in might_client_error()
#       6 def might_client_error():
#       7     print("Retry forever with no wait if any error other than ClientError occurs. Immediately raise ClientError.")
# ----> 8     raise ClientError
#       9
#      10
#
# ClientError:

# %%
from tenacity import retry_if_result


def is_none_p(value):
    """Return True if value is None"""
    return value is None

@retry(retry=retry_if_result(is_none_p(2)))
def might_return_none():
    time.sleep(0.2)
    print("Retry with no wait if return value is None")


might_return_none()
# Out:
# Retry with no wait if return value is None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-910d1f0d0d1a> in <module>
#      12
#      13
# ---> 14 might_return_none()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     402         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     403         while True:
# --> 404             do = self.iter(retry_state=retry_state)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     346
#     347         is_explicit_retry = retry_state.outcome.failed and isinstance(retry_state.outcome.exception(), TryAgain)
# --> 348         if not (is_explicit_retry or self.retry(retry_state=retry_state)):
#     349             return fut.result()
#     350
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\retry.py in __call__(self, retry_state)
#     126     def __call__(self, retry_state: "RetryCallState") -> bool:
#     127         if not retry_state.outcome.failed:
# --> 128             return self.predicate(retry_state.outcome.result())
#     129         else:
#     130             return False
#
# TypeError: 'bool' object is not callable

# %%
def is_none_p(value):
    """Return True if value is None"""
    return value is None

@retry(retry=(retry_if_result(is_none_p) | retry_if_exception_type()))
def might_return_none():
    print("Retry forever ignoring Exceptions with no wait if return value is None")


might_return_none()
# Out:
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# ...
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# Retry forever ignoring Exceptions with no wait if return value is None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6d030ec97b87> in <module>
#       8
#       9
# ---> 10 might_return_none()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     412             elif isinstance(do, DoSleep):
#     413                 retry_state.prepare_for_next_attempt()
# --> 414                 self.sleep(do)
#     415             else:
#     416                 return do
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\nap.py in sleep(seconds)
#      29     This is the default strategy, and may be mocked out for unit testing.
#      30     """
# ---> 31     time.sleep(seconds)
#      32
#      33
#
# KeyboardInterrupt:

# %%
@retry
def do_something():
    result = something_else()
    if result == 23:
       raise TryAgain


do_something()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-14903ff0e58a> in <module>
#       6
#       7
# ----> 8 do_something()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     412             elif isinstance(do, DoSleep):
#     413                 retry_state.prepare_for_next_attempt()
# --> 414                 self.sleep(do)
#     415             else:
#     416                 return do
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\nap.py in sleep(seconds)
#      29     This is the default strategy, and may be mocked out for unit testing.
#      30     """
# ---> 31     time.sleep(seconds)
#      32
#      33
#
# KeyboardInterrupt:

# %% [markdown]
# # Error Handling

# %%
@retry(reraise=True, stop=stop_after_attempt(3))
def raise_my_exception():
    raise ClientError

try:
    raise_my_exception()
except ClientError:
    ...

# %% [markdown]
# # Before and After Retry, and Logging

# %%
import logging
from tenacity import before_log

logging.basicConfig(stream=sys.stderr, level=logging.DEBUG)

logger = logging.getLogger(__name__)


class MyException(Exception):
    def __init__(self, message):
        self.message = message

    def __str__(self):
        return f"{self.__class__.__name__}(message='{self.message}')"



@retry(stop=stop_after_attempt(3), before=before_log(logger, logging.DEBUG))
def raise_my_exception():
    raise MyException("Fail")


raise_my_exception()
# Out:
# DEBUG:__main__:Starting call to '__main__.raise_my_exception', this is the 1st time calling it.
# DEBUG:__main__:Starting call to '__main__.raise_my_exception', this is the 2nd time calling it.
# DEBUG:__main__:Starting call to '__main__.raise_my_exception', this is the 3rd time calling it.
# ---------------------------------------------------------------------------
# MyException                               Traceback (most recent call last)
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     406                 try:
# --> 407                     result = fn(*args, **kwargs)
#     408                 except BaseException:  # noqa: B902
#
# <ipython-input-23-5edb2a2f7d6e> in raise_my_exception()
#      19 def raise_my_exception():
# ---> 20     raise MyException("Fail")
#      21
#
# MyException: MyException(message='Fail')
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-23-5edb2a2f7d6e> in <module>
#      21
#      22
# ---> 23 raise_my_exception()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     402         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     403         while True:
# --> 404             do = self.iter(retry_state=retry_state)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     359             if self.reraise:
#     360                 raise retry_exc.reraise()
# --> 361             raise retry_exc from fut.exception()
#     362
#     363         if self.wait:
#
# RetryError: RetryError[<Future at 0x17903efa2e0 state=finished raised MyException>]

# %% [markdown]
# # Before and After Retry, and Logging

# %%
import logging
from tenacity import before_log, after_log


logging.basicConfig(stream=sys.stderr, level=logging.DEBUG)

logger = logging.getLogger("after_log")

@retry(stop=stop_after_attempt(3), after=after_log(logger, logging.DEBUG))
def raise_my_exception():
    raise MyException("Fail")


raise_my_exception()
# Out:
# DEBUG:after_log:Finished call to '__main__.raise_my_exception' after 0.000(s), this was the 1st time calling it.
# DEBUG:after_log:Finished call to '__main__.raise_my_exception' after 0.016(s), this was the 2nd time calling it.
# DEBUG:after_log:Finished call to '__main__.raise_my_exception' after 0.016(s), this was the 3rd time calling it.
# ---------------------------------------------------------------------------
# MyException                               Traceback (most recent call last)
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     406                 try:
# --> 407                     result = fn(*args, **kwargs)
#     408                 except BaseException:  # noqa: B902
#
# <ipython-input-29-04587f19ac4d> in raise_my_exception()
#      10 def raise_my_exception():
# ---> 11     raise MyException("Fail")
#      12
#
# MyException: MyException(message='Fail')
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-29-04587f19ac4d> in <module>
#      12
#      13
# ---> 14 raise_my_exception()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     402         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     403         while True:
# --> 404             do = self.iter(retry_state=retry_state)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     359             if self.reraise:
#     360                 raise retry_exc.reraise()
# --> 361             raise retry_exc from fut.exception()
#     362
#     363         if self.wait:
#
# RetryError: RetryError[<Future at 0x17903e029a0 state=finished raised MyException>]

# %%
import logging
from tenacity import before_log, after_log, before_sleep_log

logging.basicConfig(stream=sys.stderr, level=logging.DEBUG)

logger = logging.getLogger(__name__)

@retry(stop=stop_after_attempt(3),
       before_sleep=before_sleep_log(logger, logging.DEBUG))
def raise_my_exception():
    raise MyException("Fail")


raise_my_exception()
# Out:
# DEBUG:__main__:Retrying __main__.raise_my_exception in 0.0 seconds as it raised MyException: MyException(message='Fail').
# DEBUG:__main__:Retrying __main__.raise_my_exception in 0.0 seconds as it raised MyException: MyException(message='Fail').
# ---------------------------------------------------------------------------
# MyException                               Traceback (most recent call last)
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     406                 try:
# --> 407                     result = fn(*args, **kwargs)
#     408                 except BaseException:  # noqa: B902
#
# <ipython-input-30-d3dc26953e8a> in raise_my_exception()
#      10 def raise_my_exception():
# ---> 11     raise MyException("Fail")
#      12
#
# MyException: MyException(message='Fail')
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-30-d3dc26953e8a> in <module>
#      12
#      13
# ---> 14 raise_my_exception()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     402         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     403         while True:
# --> 404             do = self.iter(retry_state=retry_state)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     359             if self.reraise:
#     360                 raise retry_exc.reraise()
# --> 361             raise retry_exc from fut.exception()
#     362
#     363         if self.wait:
#
# RetryError: RetryError[<Future at 0x17903da6d90 state=finished raised MyException>]

# %% [markdown]
# # Statistics

# %%
@retry(stop=stop_after_attempt(3))
def raise_my_exception():
    raise MyException("Fail")

try:
    raise_my_exception()
except Exception:
    ...

raise_my_exception.retry.statistics
# Out:
# {'start_time': 101836.765,
#  'attempt_number': 3,
#  'idle_for': 0,
#  'delay_since_first_attempt': 0.0}

# %% [markdown]
# # Custom Callbacks

# %%
from tenacity import stop_after_attempt, retry_if_result


def return_last_value(retry_state):
    """return the result of the last call attempt"""
    print(retry_state)
    return retry_state.outcome.result()

def is_false(value):
    """Return True if value is False"""
    return value is False

# will return False after trying 3 times to get a different result
@retry(stop=stop_after_attempt(3),
       retry_error_callback=return_last_value,
       retry=retry_if_result(is_false))
def eventually_return_false():
    return False


eventually_return_false()
# Out:
# <RetryCallState 1619267875408: attempt #3; slept for 0.0; last result: returned False>
# False

# %% [markdown]
# # Other Custom Callbacks

# %%
import logging

logging.basicConfig(stream=sys.stderr, level=logging.DEBUG)

logger = logging.getLogger(__name__)

def my_before_sleep(retry_state):
    if retry_state.attempt_number < 1:
        loglevel = logging.INFO
    else:
        loglevel = logging.WARNING

    logger.log(
        loglevel, 'Retrying %s: attempt %s ended with: %s',
        retry_state.fn, retry_state.attempt_number, retry_state.outcome)

@retry(stop=stop_after_attempt(3), before_sleep=my_before_sleep)
def raise_my_exception():
    raise MyException("Fail")

try:
    raise_my_exception()
except Exception:
    pass
# Out:
# WARNING:__main__:Retrying <function raise_my_exception at 0x00000179041ECDC0>: attempt 1 ended with: <Future at 0x17903dc1070 state=finished raised MyException>
# WARNING:__main__:Retrying <function raise_my_exception at 0x00000179041ECDC0>: attempt 2 ended with: <Future at 0x17903dc1070 state=finished raised MyException>

# %% [markdown]
# # Changing Arguments at Run Time

# %%
@retry(stop=stop_after_attempt(3))
def raise_my_exception():
    print(123)
    raise MyException("Fail")

try:
    raise_my_exception.retry_with(stop=stop_after_attempt(4))()
except Exception:
    pass

raise_my_exception.retry.statistics
# Out:
# 123
# 123
# 123
# 123
# {}

# %%
def never_good_enough(arg1):
    raise Exception('Invalid argument: {}'.format(arg1))

def try_never_good_enough(max_attempts=3):
    retryer = Retrying(stop=stop_after_attempt(max_attempts), reraise=True)
    retryer(never_good_enough, 'I really do try')

# %% [markdown]
# # Retrying code block

# %%
from tenacity import Retrying, RetryError, stop_after_attempt


try:
    for attempt in Retrying(stop=stop_after_attempt(3)):
        with attempt:
            print(123)
            raise Exception('My code is failing!')
except RetryError:
    pass
# Out:
# 123
# 123
# 123

# %%
import asyncio
from tenacity import AsyncRetrying, RetryError, stop_after_attempt


async def function():
   try:
       async for attempt in AsyncRetrying(stop=stop_after_attempt(3)):
           with attempt:
               print(123)
               raise Exception('My code is failing!')
   except RetryError:
       pass


await function()
# Out:
# 123
# 123
# 123

# %% [markdown]
# # Async and retry

# %%
import time


@retry
async def my_async_function(loop):
    time.sleep(1)
    print(123)
    await loop.getaddrinfo('8.8.8.8', 53)


# await my_async_function(123)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-8-19ec8b48c705> in <module>
#       9
#      10
# ---> 11 await my_async_function()
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\_asyncio.py in async_wrapped(*args, **kwargs)
#      84         @functools.wraps(fn)
#      85         async def async_wrapped(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 86             return await fn(*args, **kwargs)
#      87
#      88         # Preserve attributes
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\_asyncio.py in __call__(self, fn, *args, **kwargs)
#      56             elif isinstance(do, DoSleep):
#      57                 retry_state.prepare_for_next_attempt()
# ---> 58                 await self.sleep(do)
#      59             else:
#      60                 return do
#
# D:\bigdata\anaconda3\envs\py39\lib\asyncio\tasks.py in sleep(delay, result, loop)
#     632     """Coroutine that completes after a given time (in seconds)."""
#     633     if delay <= 0:
# --> 634         await __sleep0()
#     635         return result
#     636
#
# D:\bigdata\anaconda3\envs\py39\lib\asyncio\tasks.py in __sleep0()
#     626     instead of creating a Future object.
#     627     """
# --> 628     yield
#     629
#     630
#
# CancelledError:

# %%
await my_async_function(123)
# Out:
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-9-52e7efa31d6e> in <module>
# ----> 1 await my_async_function(123)
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\_asyncio.py in async_wrapped(*args, **kwargs)
#      84         @functools.wraps(fn)
#      85         async def async_wrapped(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 86             return await fn(*args, **kwargs)
#      87
#      88         # Preserve attributes
#
# D:\bigdata\anaconda3\envs\py39\lib\site-packages\tenacity\_asyncio.py in __call__(self, fn, *args, **kwargs)
#      56             elif isinstance(do, DoSleep):
#      57                 retry_state.prepare_for_next_attempt()
# ---> 58                 await self.sleep(do)
#      59             else:
#      60                 return do
#
# D:\bigdata\anaconda3\envs\py39\lib\asyncio\tasks.py in sleep(delay, result, loop)
#     632     """Coroutine that completes after a given time (in seconds)."""
#     633     if delay <= 0:
# --> 634         await __sleep0()
#     635         return result
#     636
#
# D:\bigdata\anaconda3\envs\py39\lib\asyncio\tasks.py in __sleep0()
#     626     instead of creating a Future object.
#     627     """
# --> 628     yield
#     629
#     630
#
# CancelledError:

# %%
import time


@retry
@tornado.gen.coroutine
def my_async_function(http_client, url):
    yield http_client.fetch(url)

# %%
@retry(sleep=trio.sleep)
async def my_async_function(loop):
    await asks.get('https://example.org')


await my_async_function()
