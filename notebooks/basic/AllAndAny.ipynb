# %%
any(i % 2 == 0 for i in range(5))
# Out:
# True

# %%
all(i % 2 == 0 for i in range(5))
# Out:
# False

# %%
any(i % 2 == 0 for i in range(0, 11, 2))
# Out:
# True

# %%
all(i % 2 == 0 for i in range(0, 11, 2))
# Out:
# True
