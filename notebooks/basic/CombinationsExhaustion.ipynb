# %% [markdown]
# # 使用 `combinations` 进行暴力穷举

# %%
from itertools import combinations

# %%
lst = list("abcd")

for e in combinations(lst, 2):
    print(e)
# Out:
# ('a', 'b')
# ('a', 'c')
# ('a', 'd')
# ('b', 'c')
# ('b', 'd')
# ('c', 'd')

# %%
for e in combinations(lst, 3):
    print(e)
# Out:
# ('a', 'b', 'c')
# ('a', 'b', 'd')
# ('a', 'c', 'd')
# ('b', 'c', 'd')
