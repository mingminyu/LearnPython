# %% [markdown]
# # 槽值 (slots) 的使用方法

# %% [raw]
# 💡 __slots__ 相当于限制了类中可以使用的属性
# 💡 __slots__ 可以节省内存，以及加快运算速度
# 💡 源码实现需要解读 Cython，后续再了解

# %%
class C:
    ...


c = C()
c.f = 123

# %% [markdown]
# 由于 Python 类的特殊性，我们可以随意给类实例添加属性，这在很多时间非常不安全。

# %%
import time
from typing import Union

# %%
class A:
    __slots__ = ('f', 'g')

    def __call__(self, *args, **kwargs):
        ...


class B:
    def __call__(self, *args, **kwargs):
        ...


# noinspection PyPep8Naming
def timeit(className: Union[A, B]):
    p = className()
    start = time.time()

    for _ in range(10000000):
        p.f = 2

    print(className.__name__, time.time() - start)

# %%
a = A()
a.f = 2

# %%
a.c = 123
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6e6505f3f206> in <module>
# ----> 1 a.c = 123
#
# AttributeError: 'A' object has no attribute 'c'

# %%
timeit(A)
# Out:
# A 2.4986417293548584

# %%
timeit(B)
# Out:
# B 2.5302133560180664
