# %% [markdown]
# # Usages of pass and ...

# %% [markdown]
# `pass` 和 `...` 主要用于在定义一个函数之后，暂时还不知道写什么逻辑，可以使用 `pass` 或者 `...` 来先完善函数体

# %%
# %%timeit
def func_pass():
    pass
# Out:
# 58.2 ns ± 3.18 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
def func_three_dots():
    ...
# Out:
# 57.4 ns ± 2.85 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# 根据上述示例可以总结出 2 点：
#
# - `···` 是一个省略(Ellipsis)对象
# - 使用 `...` 还比 `pass` 更快一些
