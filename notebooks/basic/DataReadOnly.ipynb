# %%
fs = frozenset([1, 2, 3, 4, 1])

for e in fs:
    print(e)
# Out:
# 1
# 2
# 3
# 4

# %%
from types import MappingProxyType

# %%
dic = {"a": 1, "b": 2}
mp = MappingProxyType(dic)
mp
# Out:
# mappingproxy({'a': 1, 'b': 2})

# %% [markdown]
# 集合中是不可以嵌套集合的，但是字典是可以的

# %%
dic2 = {"a": 1, "b": [1, 2]}
dic3 = {"a": 1, "b": [1, 2], "c": (3, 4)}
dic4 = {"a": 1, "b": [1, 2], "c": (3, 4), "d": {"z1": 2}}

# %%
s = {1, 2, {3}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-cd2a1de4bb24> in <module>
# ----> 1 s = {1, 2, {3}}
#
# TypeError: unhashable type: 'set'

# %%
s = {1, 2, frozenset({3})}
s
# Out:
# {1, 2, frozenset({3})}
