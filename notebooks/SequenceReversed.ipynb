# %% [markdown]
# # 字符串

# %%
str1 = "abcd"
str2 = str1[::-1]

str1, str2
# Out:
# ('abcd', 'dcba')

# %%
"".join(reversed(str1))
# Out:
# 'dcba'

# %% [markdown]
# # 列表

# %%
lst = [1, 2, 3, 4]
lst.reverse()  # 操作会改变本身
print(lst)
# Out:
# [4, 3, 2, 1]
